# %%
import os
from time import time
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest

# %%
quandl_df = pd.read_csv("quandl.csv")
goog_df = pd.read_csv("goog.csv")
GQ_df = quandl_df.merge(goog_df, how="inner", on=["ticker", "date"])

# %%
GQ_df.columns
# Out:
# Index([u'Open', u'High', u'Low', u'Close', u'Volume', u'date', u'50dravg',
#        u'200dravg', u'OC%', u'HL%', u'OH%', u'LastOpen', u'LastHigh',
#        u'LastLow', u'LastClose', u'LastVolume', u'LastOC%', u'LastHL%',
#        u'LastOH%', u'ticker', u'label', u'CLOSE_x', u'CLOSE_y', u'HIGH_x',
#        u'HIGH_y', u'LOW_x', u'LOW_y', u'OPEN_x', u'OPEN_y', u'VOLUME_x',
#        u'VOLUME_y', u'lo_hi%_x', u'lo_hi%_y', u'op_cl%_x', u'op_cl%_y',
#        u'time_x', u'time_y', u'volume_change', u'volume_change_perc',
#        u'week_day_x', u'week_day_y'],
#       dtype='object')

# %%
GQ_df['date'].unique()
# Out:
# array(['2015-06-29', '2015-06-30', '2015-07-02', '2015-07-06',
#        '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10',
#        '2015-07-13', '2015-07-14', '2015-07-15', '2015-07-16',
#        '2015-07-17', '2015-07-20', '2015-07-21', '2015-07-22',
#        '2015-07-23', '2015-07-24', '2015-07-27', '2015-07-28',
#        '2015-07-29', '2015-07-30', '2015-07-31', '2015-08-03',
#        '2015-08-04', '2015-08-05', '2015-08-06', '2015-06-26',
#        '2015-08-24', '2015-06-22', '2015-06-23', '2015-06-24',
#        '2015-06-25', '2015-07-01', '2015-08-07', '2015-08-10',
#        '2015-08-11', '2015-08-12', '2015-08-13', '2015-08-14',
#        '2015-08-17', '2015-08-18', '2015-08-19', '2015-08-20',
#        '2015-08-21', '2015-08-25', '2015-08-26', '2015-08-27'], dtype=object)

# %%
GQ_df['label'] = (GQ_df['Close'] / GQ_df['Open']) - 1
GQ_df = GQ_df.replace([np.inf, -np.inf], np.nan)
GQ_df = GQ_df.dropna()
GQ_df.to_csv('GQ.csv', index=False)

# %%
X_df = GQ_df[['50dravg', '200dravg', 'LastOpen', 'LastHigh', 'LastLow', 'LastClose', 'LastVolume', 'LastOC%', 'LastHL%', 'LastOH%', 'CLOSE_x', 'HIGH_x', 'LOW_x', 'OPEN_x', 'VOLUME_x', 'op_cl%_x', 'lo_hi%_x', 'volume_change', 'volume_change_perc']]
#X_df = GQ_df.drop(['date','label'], axis=1)
#X_df['ticker'] = X_df['ticker'].astype('category').cat.codes
X = X_df.values.astype('float32')
print X.shape
print X[0].shape
print X[0]
# Out:
# (2187, 19)
# (19,)
# [  8.62200022e-01   9.05250013e-01   1.00000000e+00   1.23000002e+00
#    1.00000000e+00   1.04999995e+00   3.87010000e+06   5.00000007e-02
#    2.30000004e-01   2.30000004e-01   1.04999995e+00   1.04999995e+00
#    1.04999995e+00   1.04999995e+00   7.35900000e+03   0.00000000e+00
#    0.00000000e+00   9.64850000e+04   1.31111565e+01]

# %%
Y_df = GQ_df.loc[:, 'label'].map(lambda x: 1 if x >= 0.02 else 0)
Y = Y_df.values.astype('float32')
print Y.shape
print Y[0].shape
print Y[0]
plt.hist(Y, bins=50)
plt.show()
# Out:
# (2187,)
# ()
# 0.0

# %%
# BALANCE
balance_labeled_data = False
# BALANCE LABELS
if balance_labeled_data == True:
    # randomly balance labeled data
    indices_Y_is_0 = np.where(Y == 0)[0]
    #print indices_Y_is_0.shape[0]
    indices_Y_is_1 = np.where(Y == 1)[0]
    #print indices_Y_is_1.shape[0]

    subset_indices_Y_is_0 = np.random.choice(indices_Y_is_0, indices_Y_is_1.shape[0])
    X_is_0 = X[subset_indices_Y_is_0]
    Y_is_0 = Y[subset_indices_Y_is_0]
    X_is_1 = X[indices_Y_is_1]
    Y_is_1 = Y[indices_Y_is_1]

    X = np.concatenate((X_is_0,X_is_1))
    Y = np.concatenate((Y_is_0,Y_is_1))

    plt.hist(Y)
    plt.show()

# %%
skb = SelectKBest()
skb.fit(X,Y)
cols = X_df.columns
for i in xrange(cols.shape[0]):
    print cols[i], skb.scores_[i]
# Out:
# 50dravg 0.0420349
# 200dravg 1.53215
# LastOpen 0.000764648
# LastHigh 0.00073023
# LastLow 0.0555198
# LastClose 0.0295573
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# LastOH% 0.0807373
# CLOSE_x 0.128997
# HIGH_x 0.121835
# LOW_x 0.163429
# OPEN_x 0.155472
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# volume_change_perc 1.35633

# %%
# BREAK UP DATA
X_train, X_val_test, y_train, y_val_test = train_test_split(X, Y, test_size=0.3, random_state=42)
X_validation, X_test, y_validation, y_test = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# SCALE
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %% [markdown]
# ---

# %%
from nn import *
# RANDOM SEARCH
for i in xrange(10):
    NN(X_df.columns,X,Y)
# Out:
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# ----------
# features 8
# outputs 2
# h1 86
# h2 93
# W1 (86, 8)
# b1 (86, 1)
# W2 (93, 86)
# b2 (93, 1)
# W3 (2, 93)
# b3 (2, 1)
# ----------
# h1: 86 h2: 93 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 0.001
# last mean validation loss: 0.68
# last mean training loss: 0.69
# h1: 86 h2: 93 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 1.44692874144e-30
# last mean validation loss: 0.68
# last mean training loss: 0.68
# 200dravg 1.53215
# LastLow 0.0555198
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# LastOH% 0.0807373
# CLOSE_x 0.128997
# HIGH_x 0.121835
# LOW_x 0.163429
# OPEN_x 0.155472
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# volume_change_perc 1.35633
# ----------
# features 15
# outputs 2
# h1 97
# h2 27
# W1 (97, 15)
# b1 (97, 1)
# W2 (27, 97)
# b2 (27, 1)
# W3 (2, 27)
# b3 (2, 1)
# ----------
# h1: 97 h2: 27 epochs: 50 Lambda: 1.0 Reg: L1 alpha: 0.1
# last mean validation loss: 0.69
# last mean training loss: 0.79
# h1: 97 h2: 27 epochs: 50 Lambda: 1.0 Reg: L1 alpha: 2.70789562817e-27
# last mean validation loss: 0.69
# last mean training loss: 0.74
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# LOW_x 0.163429
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# volume_change_perc 1.35633
# ----------
# features 10
# outputs 2
# h1 23
# h2 109
# W1 (23, 10)
# b1 (23, 1)
# W2 (109, 23)
# b2 (109, 1)
# W3 (2, 109)
# b3 (2, 1)
# ----------
# h1: 23 h2: 109 epochs: 50 Lambda: 0.001 Reg: L2 alpha: 0.001
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 23 h2: 109 epochs: 50 Lambda: 0.001 Reg: L2 alpha: 1.52726706603e-33
# last mean validation loss: 0.69
# last mean training loss: 0.69
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# ----------
# features 8
# outputs 2
# h1 15
# h2 11
# W1 (15, 8)
# b1 (15, 1)
# W2 (11, 15)
# b2 (11, 1)
# W3 (2, 11)
# b3 (2, 1)
# ----------
# h1: 15 h2: 11 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 0.0001
# last mean validation loss: 0.8
# last mean training loss: 0.71
# h1: 15 h2: 11 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 1.52726706603e-34
# last mean validation loss: 0.77
# last mean training loss: 0.7
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# ----------
# features 8
# outputs 2
# h1 88
# h2 20
# W1 (88, 8)
# b1 (88, 1)
# W2 (20, 88)
# b2 (20, 1)
# W3 (2, 20)
# b3 (2, 1)
# ----------
# h1: 88 h2: 20 epochs: 50 Lambda: 0.01 Reg: L1 alpha: 0.1
# last mean validation loss: 0.67
# last mean training loss: 0.77
# h1: 88 h2: 20 epochs: 50 Lambda: 0.01 Reg: L1 alpha: 1.16786727749e-30
# last mean validation loss: 0.68
# last mean training loss: 0.73
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# CLOSE_x 0.128997
# LOW_x 0.163429
# OPEN_x 0.155472
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# volume_change_perc 1.35633
# ----------
# features 12
# outputs 2
# h1 25
# h2 18
# W1 (25, 12)
# b1 (25, 1)
# W2 (18, 25)
# b2 (18, 1)
# W3 (2, 18)
# b3 (2, 1)
# ----------
# h1: 25 h2: 18 epochs: 50 Lambda: 0.01 Reg: L2 alpha: 0.001
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 25 h2: 18 epochs: 50 Lambda: 0.01 Reg: L2 alpha: 1.52726706603e-33
# last mean validation loss: 0.69
# last mean training loss: 0.68
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# LastOH% 0.0807373
# CLOSE_x 0.128997
# HIGH_x 0.121835
# LOW_x 0.163429
# OPEN_x 0.155472
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# volume_change_perc 1.35633
# ----------
# features 14
# outputs 2
# h1 82
# h2 104
# W1 (82, 14)
# b1 (82, 1)
# W2 (104, 82)
# b2 (104, 1)
# W3 (2, 104)
# b3 (2, 1)
# ----------
# h1: 82 h2: 104 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 0.1
# last mean validation loss: 0.69
# last mean training loss: 0.72
# h1: 82 h2: 104 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 1.52726706603e-31
# last mean validation loss: 0.69
# last mean training loss: 0.68
# VOLUME_x 37.7006
# volume_change 22.5883
# ----------
# features 2
# outputs 2
# h1 47
# h2 94
# W1 (47, 2)
# b1 (47, 1)
# W2 (94, 47)
# b2 (94, 1)
# W3 (2, 94)
# b3 (2, 1)
# ----------
# h1: 47 h2: 94 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 0.001
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 47 h2: 94 epochs: 50 Lambda: 0.0001 Reg: L1 alpha: 1.44692874144e-30
# last mean validation loss: 0.69
# last mean training loss: 0.69
# 200dravg 1.53215
# LastVolume 6.71355
# LastOC% 4.39473
# LastHL% 3.31506
# CLOSE_x 0.128997
# LOW_x 0.163429
# OPEN_x 0.155472
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# volume_change_perc 1.35633
# ----------
# features 12
# outputs 2
# h1 21
# h2 44
# W1 (21, 12)
# b1 (21, 1)
# W2 (44, 21)
# b2 (44, 1)
# W3 (2, 44)
# b3 (2, 1)
# ----------
# h1: 21 h2: 44 epochs: 50 Lambda: 1.0 Reg: L1 alpha: 0.1
# last mean validation loss: 0.69
# last mean training loss: 0.85
# h1: 21 h2: 44 epochs: 50 Lambda: 1.0 Reg: L1 alpha: 1.16786727749e-30
# last mean validation loss: 0.69
# last mean training loss: 0.77
# LastVolume 6.71355
# LastOC% 4.39473
# VOLUME_x 37.7006
# op_cl%_x 6.29325
# lo_hi%_x 11.7165
# volume_change 22.5883
# ----------
# features 6
# outputs 2
# h1 84
# h2 17
# W1 (84, 6)
# b1 (84, 1)
# W2 (17, 84)
# b2 (17, 1)
# W3 (2, 17)
# b3 (2, 1)
# ----------
# h1: 84 h2: 17 epochs: 50 Lambda: 0.0001 Reg: L2 alpha: 0.01
# last mean validation loss: 0.67
# last mean training loss: 0.68
# h1: 84 h2: 17 epochs: 50 Lambda: 0.0001 Reg: L2 alpha: 1.52726706603e-32
# last mean validation loss: 0.66
# last mean training loss: 0.65

# %% [markdown]
# ---
